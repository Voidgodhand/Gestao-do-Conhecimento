# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# DISCIPLINA: Gestão do Conhecimento	 PROFESSOR(A): Alex Salgado
# PERÍODO: 7o. TURNO: noite AVALIAÇÃO:
#
# ALUNOS(AS): João Gabriel Alegria Napoleão, matrícula: 005001804; David Bastos de Souza Tinôco, matrícula: 0050011100
#
# GRAU: VISTO DO PROFESSOR:

# %% [markdown]
# # Questão 1 - valor (0,0)

# %% [markdown]
# *** Crie um repositório no Github e adicione este arquivo no mesmo
#
#
# 1.1 - Você deve escolher uma base de dados aberta que seja possível treinar um modelo de aprendizagem de máquina Supervisionado de Classificação (assim como o exemplo da Iris e Cancer). A partir desta base de dados, você vai treinar o modelo, fazer previsões e calcular a acurácia do mesmo.
# Obs.: Não utilizar nenhuma base de dados usada em aula,  nos trabalhos ou na biblioteca do sklearn.

# %% [markdown]
# 1.1 - Descreva aqui o que sua base de dados guarda.

# %% [markdown]
# Esta base de dados guarda valores numéricos que quantificam diversas características sobre notícas online do site Mashable

# %% [markdown]
# 1.2 - Após tratada, criar uma pasta no seu GoogleDrive e disponibilizar o link do arquivo de sua base (csv, xlsx, etc) para ser importado no seu código.

# %% [markdown]
# https://drive.google.com/file/d/1eeIPVrRfg8e6BynYhXl0EqAboZW42ANK/view?usp=sharing

# %% [markdown]
# ## Criar um código usando o Jupyter Notebook e responder (através de código) às seguintes questões:

# %% [markdown]
# # Questão 2 - valor (0,5)

# %% [markdown]
# 2.1 - Importar os modulos python para machine learn e carregar o arquivo
#
# ** Sugestão se for do tipo xlsx, usar o read_excel do pandas
# import pandas as pd
# dt = pd.read_excel("meuarquivo.xlsx")

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/OnlineNewsPopularity.csv', header=0)

# %% [markdown]
# 2.2 - Exibir os primeiros registros desta tabela.

# %%
data.head()
# Out:
#    n_tokens_title  n_tokens_content  ...  abs_title_sentiment_polarity  shares
# 0            12.0             219.0  ...                  1.875000e+03     593
# 1             9.0             255.0  ...                  0.000000e+00     711
# 2             9.0             211.0  ...                  0.000000e+00    1500
# 3             9.0             531.0  ...                  0.000000e+00    1200
# 4            13.0            1072.0  ...                  1.363636e+11     505
#
# [5 rows x 59 columns]

# %% [markdown]
# 2.3 - De que se trata esse banco de dados? e que tipo de previsão pode ser feito com ele?

# %% [markdown]
# Esse banco de dados se trata de informações numéricas sobre notícias do site Mashable, como número de palavras no título, número de links, imagens e vídeos presentes na notíca. Com ele, podem ser feitas previsões de clasificação e de regressão.

# %% [markdown]
# # Questão 3 - valor (0,5)

# %% [markdown]
# Utilizando as terminologias de Machine Learning(features e observações):

# %% [markdown]
# 3.1 - Quantas "features" têm nessa base de dados?

# %%
#59-1 = 58 features
data.shape
# Out:
# (998, 59)

# %% [markdown]
# 3.2 - Quantas observações têm nessa base de dados?

# %%
#998 observações
data.shape
# Out:
# (998, 59)

# %% [markdown]
# # Questão 4 - valor (1,0)

# %% [markdown]
# 4.1 - Faça uma previsão, usando o algoritmo de LogisticRegression.

# %%
X=data.iloc[:,0:58]
X
# Out:
#      n_tokens_title  ...  abs_title_sentiment_polarity
# 0              12.0  ...                  1.875000e+03
# 1               9.0  ...                  0.000000e+00
# 2               9.0  ...                  0.000000e+00
# 3               9.0  ...                  0.000000e+00
# 4              13.0  ...                  1.363636e+11
# ..              ...  ...                           ...
# 993             4.0  ...                  1.555556e+11
# 994             7.0  ...                  0.000000e+00
# 995            13.0  ...                  0.000000e+00
# 996            10.0  ...                  3.333333e+11
# 997             8.0  ...                  3.500000e-01
#
# [998 rows x 58 columns]

# %%
y=data['shares']
y
# Out:
# 0       593
# 1       711
# 2      1500
# 3      1200
# 4       505
#        ...
# 993    2300
# 994    4000
# 995     785
# 996    2400
# 997    2300
# Name: shares, Length: 998, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X, y)
y_pred = logreg.predict(X)
y_pred
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# array([  593,   711,  1500,  2300,   505,   855,   695,   891,  3600,
#          710,  1200,   462,   823, 10000,   761,   495, 13600,  2300,
#         5700, 17100,  2800,   598,   445,   783,   852,   783,  2800,
#         1900,   462,   425,  3200,  3900,   480,   573,  3600,   343,
#          507,  1400,   504,  3200,   657,   401,  1300,   891,   500,
#          575,   507,  4600,   695,  3300,  1600,   382,   400,  1200,
#         1600,   343,  1300,  2300,   819,   585,   536,   834,   645,
#          598,   217,  2700,   545,  1800,  1200,   732,  1600,  2800,
#          495,   690,  1200,   552,   631,  4800,   851,   755,   468,
#         4600,  1200,  2000,  2300,  1200,  1200,  1800,  1200,  1200,
#          500,   455,  1800,   459,  2300,  6400,  4800,  1300,   341,
#         1200,  1400,   450,   663,   302,   971,  4000,  3400,  1600,
#         2000,   217,  3000,  1200,  5700,  7100,  5700,   705,  1100,
#         1200,  2400,   575,  1900,  2000,  1600,  1700,  1900,  9200,
#         4800,  6000,   752, 19400,  2000,  1500,   788,   454,  1500,
#         2200,  1000,  1500,   412,  1100,   417,  3100,  2100,   474,
#         2100,   513, 10400,  1700,  5600,   373,  1300,  1500,   657,
#         1900,   727,   350,  1200,  2800,  1900,   341,   648,  1200,
#         2600,  3800,  1700,  4600,  1200,  2800,   450,   939,  1600,
#          866,   606,  5000, 11500,   529, 28000,  1300,   761,   958,
#          904,  1100,  4500,  1200,   427,  1900,  1600,   377,  3100,
#          972,   979,   737,  1100,   396,  1500,   676,  2900,  1800,
#         2000,   484,  7500,   441,   922,   473,  2400,  1600,  1300,
#         3800,  5600,  8100,  5500,  1100,   933,  1400,  3100,  2300,
#        11400,   308,  2400,   762,  1200,   657,   438, 11800,  2400,
#          794,  2600,  1200,  1200,  1500,  3500,   698,  1100,   742,
#         1000,  1900,  2300,  4400,   751,   775,   569,  1700,  1600,
#         2100,   979,   802,  1500,   835,  1100, 12000,   423,  1000,
#         2700,  1400,  2000,  1100,  1100,  1000,  2000,   400,  1600,
#         1100,  1100,  1300,  1400,   924,  2800,   902,  1300,  1300,
#        37400, 18000,  2500, 18200,   924,   730,  3000,  3100,   614,
#         1800,  1600,  1100,  1600,  2400,   582,  1300,   606,   720,
#        19800,  1900,  3000,  1500,  4400,  2000,  1200,  1000,  1900,
#         3800,   840,  4000,  1100,  1400,  1100,  9000,   622,  1000,
#          658,  1300,  2600,  2200,  5200,  5300,  1500,  6300,  2900,
#         1100,  1200,  1700,  1100,  1400,  2100,  1700,  1100,  2700,
#        25200, 15700,  3400,  2200,  2300,  1500,  1100,  7900,   731,
#         2900,  3100,  1900,  9700,  1000,   894,  1400,  6000, 12100,
#         3000,  1100,  1500,  1400,  1100,  2800, 14300, 33100,  3400,
#         5400,  1200,   618,  1500,  8000,   630,  1100,  5800,   465,
#         1000,   909,   705,  2700,   699,  1200,  3200,   636,   432,
#         3000,   621,  5300,  1600,  1500,   649,   476,  1300,  1300,
#         2100,  1600,   586,  1700,   992,   950,   903,  1500,  1300,
#         2100,  1300,  1200,  1100,  1000,   862,  4600,  1500,  4900,
#          462,  1300,  1100,  3000,   727,  1200,  3700, 10400,  2100,
#         1400,   884,  2100,   645,   429, 39400,   811,  5200,   756,
#         1200,  1200,  6500,   440,   983,  1300,  1600,  1900,  1200,
#          735,  1100,   718,  1400,  1300,   544,  2400,  2500,  2400,
#         2000,   581,  6800,   752,   866,  5000,  3500,  1200,   442,
#         1600,  1900,  2100,  1900,  2400,  1100,  5900,   458,  5100,
#         1600,   462,  1500,  1200,   593,  4200,  5400,  1100,  3800,
#          725,   787,  8900,  5500,  1900,   463,   368,  1000,   957,
#         1200,   484, 17100,  1300,  1600,  1600,  2400,  1100,   568,
#         4200,  1300,   968,   529,  1800,   768,   635,  1300,  4800,
#          685,  1400,  6300,  1400,  1900,  2800,  1300,  1000,   824,
#         5100,  1900,  3000,   933,   480,  4400,  2400,   660,  1200,
#         2500,   757,  1300,   514,  1600,  1100,  1300,  1300,   615,
#         1600,  3200,  4200,  1300,  2800,  1700,  2000,  2200,   416,
#          900,   529,   354,   483,   575,  1200,  3400,  2300,  1300,
#         1300,  4400,  1100,  2100,  6400, 17300,   504,  1400,  1700,
#         1500,   560,  2000,  1600, 11400,  4500,   782,  2100,  8300,
#          811,  2800,  4100,  1600,  9100,  5700,  3400,   460,   554,
#          638,   712,  1200,  3000,   438,  3100, 51900,   935,   832,
#          804,  3500,   864,  3000,  1200,   847,   917,  2600,   673,
#          938,   358,  1300,  1000,   672,  1300,  2100,  1200,  1200,
#         5400,   610,   870,   835,  1600,  2400,  1100,  1300,   793,
#         1200,  2400,   704,  4800, 12300,   833,  4900,  2900,   844,
#          744,  1100,   690,   998,  3300,  2900,  1000,  4000,  1100,
#         5100,  3200,   802,  1100,  4200,   875,  2500,  1100,  5000,
#         1200,   715,  1200,   801,  4200,  1100,   756,   592,  1100,
#         1100,  2800,  1100,  2900,  1300,  9100,  5700,  3100,  7200,
#          671,  1100,  1100,  3500,  2000,   817,  3400,  1300,   771,
#        15800,   794,   465,  1700,  1200,   577, 17500,  1400,  2200,
#          536,  3000,  3300,  1000,  5700,  3100,   701,  8000,  3600,
#         1200,  2900,   884,   573,  1900,  1800,  5800,   721,  1200,
#         2900,  1300,  1100,   657,  1200,  2100,  1300,  1300,   561,
#         1200,   715,  1100,  1400,  1200,   930,  1500,  1100,  1300,
#         3000,  2000,  1600,   400,  1700,  1200,  2300,  2200,  1100,
#         1300,  2700,  1500,  2200,  1300,  1000,  7700,  1800,  1200,
#         1700,  1600,  2000,  1800,  2600,  3500,  1800,  7800,  7800,
#          560,  5800,  2800,  9800,  2400,  3900,  1800,  1600,  2500,
#         1700,  4400,  1600, 17600,   767,  2400,  1100,  2800,  2000,
#         5700,  1500,   657,  2100,  1800,   827,   876,  1000,   764,
#         1100,  4000,  2900,  2500,   423,  1100,  1400,  3200,   703,
#         1100,  1100,   863,  2100,  1100,  1400,  3700,   799,  5800,
#         1400,  1200,  1700,   504,  1300,  1100,  6300,  2200,   800,
#         2200,  1200,   900,  1100,  1100,  1600,  2000,  2900,  1100,
#          950,  1300,   971,   872,  6300,   657,  2500,  1100,  1700,
#          718,  4500,  5300,   533,  6800,  1100,  1500,  6500,  1000,
#          987,  6700,  4100,   428,  1500,  2900,   782,  3500,   936,
#         1800,  5300,   860,  1700,   925, 11900,  1300,   940,  1500,
#         1100,  1500,  1100,  1200,  6000,  1300,  1900,  2200,   583,
#         1100,  5400,   504,  6500,  2100,   751,   741,  1100,  1800,
#         1600,   635,   589,  1100,   473,  2500,  1500,  2400,  1000,
#          532,  3100,  1400,   510,   342,  1700,  1300,  3400, 22000,
#          503,  3200,  1100,   522,  1200,   847,  1200,  5700,  5500,
#         2300,  3700,   823,  1900,  5600,  2900,  1900,   689,  1100,
#         1200,  1100,   952,   300,  1700,  3700,   498,  1200,  2700,
#         1500,  1800,  2000,  1800,  8200,  1000,  1700,  2800,   899,
#          956,  1000,   884,   915,  2000,   864,  4100,   910,   790,
#          623,   548,  1100,  2600,   508,  1600,   909,   999,  2100,
#          825,  2500,  1300,  1200,  1000,  1000,  1100,  2700,  3000,
#         3000,  1300,  3100, 10200,   603,  1300,  2500,   957,   899,
#         2700,  1700,  1700,  8200,  1100,   683,   866,   371,   811,
#         7400,  2700,   375,   799,   445,   837,   978,  1600,   427,
#         3000,   929,  1200,  1100,  1100,   513,  1200,   560,  8300,
#         8300,   740,   581,   556,  1300,   775,   518,  1700,  4700,
#         1700,   673,   886,  6000,  1400,  3900, 39200,   876,  2100,
#         1600,   755,  6000,  1000,   555, 13800,   447,  4400,  4900,
#          462,  1200,  8200,  1000,  1000,  1100,  9500,  1400,   949,
#          405,  2100,  2400,  2300,  1100,   785,  1800,  2300])

# %% [markdown]
# # Questão 5 - valor (1,5)

# %% [markdown]
# Usando o método de avaliação de acurácia (Treinar e testar na base de dados inteira/Train test entire model), Calcular a acurácia de cada um dos 3 métodos abaixo.

# %% [markdown]
# 4.1 - Acurácia usando o algoritmo de KNN (com 1 vizinho, k=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X, y)
y_pred = knn.predict(X)
print(metrics.accuracy_score(y, y_pred))
# Out:
# 1.0

# %% [markdown]
# 4.2 - Acurácia usando o algoritmo de KNN (com 5 vizinho, k=5)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X, y)
y_pred = knn.predict(X)
print(metrics.accuracy_score(y, y_pred))
# Out:
# 0.21442885771543085

# %% [markdown]
# 4.3 - Acurácia usando o algoritmo de LogisticRegression

# %%
logreg = LogisticRegression()
logreg.fit(X, y)
y_pred = logreg.predict(X)
from sklearn import metrics
print(metrics.accuracy_score(y, y_pred))
# Out:
# 0.5370741482965932
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# 4.4 - De acordo com seus resultados anteriores, qual dos 3 métodos é mais eficiente?

# %% [markdown]
# De acordo com os resultados anteriores, o método mais eficiente é o algoritmo de knn com 1 vizinho.

# %%
*** Envie o link do seu Github com essa resposta no Classroom
