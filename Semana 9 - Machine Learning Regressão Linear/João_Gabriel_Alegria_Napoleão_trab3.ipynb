# %% [markdown]
# Aluno: João Gabriel Alegria Napoleão, matrícula: 0050013804

# %%
import pandas as pd # conventional alias
from sklearn.datasets import load_boston

dataset = load_boston()

# %%
dataset
# Out:
# {'DESCR': ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate
# ...

# %%
data = pd.read_csv('/usr/local/lib/python3.6/dist-packages/sklearn/datasets/data/boston_house_prices.csv', header=1)

# %% [markdown]
# 1-Mostre os primeiros registros da tabela

# %%
#1 - Primeiros registros da tabela
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# 2-Observações(linhas) possui nessa base? Quantas Colunas?

# %%
#2 - numero de observações (linhas) e colunas
data.shape
# Out:
# (506, 14)

# %% [markdown]
# 3-Quantas Features Possui?

# %%
#3 - numero de features
feature_cols=list(dataset.feature_names)
count=0
for n in feature_cols:
  count=count+1
count
# Out:
# 13

# %% [markdown]
# 4-Qual é o campo Target(respostas) dessa base?

# %%
dataset.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
#4 - campo target (fora dos 'feature_names' do dataset): MEDV
data['MEDV']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# 5-Usando a biblioteca de visualização seaborn, plote o gráfico que mostra a relação entre as features e responses

# %%
#5 - plotagem do gráfico, com relação entre features e responses
import seaborn as sns

# %matplotlib inline

sns.pairplot(data, x_vars=['CRIM','CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'], y_vars='MEDV', height=7 ,aspect=1, kind='reg')

# %% [markdown]
# 6-Prepare X e y usando o pandas

# %%
#6 - Preparando X
X=data[feature_cols]

# %%
#6- Preparando y
y=data['MEDV']

# %% [markdown]
# 7-Qual o tipo de dados de X e y?

# %%
#7 - Tipo de X
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
#7 - Tipo de y
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# 8-Sobre o que se trata essa base de dados? Que tipo de informações ela guarda?

# %% [markdown]
# Essa base de dados se trata sobre avaliações imobiliárias de Boston. Ela guarda valores float para features como taxa de crime per capita ("CRIM") e índice de acessibilidade a rodovias radiais ("RAD"), além de seu target, "MEDV", ser o valor médio de casas ocupadas por moradores, em milhares de dólares.

# %% [markdown]
# 9-Gere um X de treino e y de treino, X de teste e y da base (Split Train/Test)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# 10-Qual o percentual gerado para criar o conjunto de treino e o conjunto de teste?

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (379, 13)
# (379,)
# (127, 13)
# (127,)

# %%
#percentual gerado para o conjunto de treino
379/(379+127)*100
# Out:
# 74.90118577075098

# %%
#percentual gerado para o conjunto de teste
127/(379+127)*100
# Out:
# 25.09881422924901

# %% [markdown]
# 11-Usando modelo de regressão linear do sklearn, treine o modelo com o X e y de treino

# %%
from sklearn.linear_model import LinearRegression

linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# 12-Imprima os atributos de "intercept" e "coefficients" que foram gerados

# %%
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 45.192515388385075
# [-1.14428903e-01  5.71299780e-02  3.83002824e-02  2.42854641e+00
#  -2.12326236e+01  2.87723416e+00  6.91118094e-03 -1.47158266e+00
#   3.05784197e-01 -1.06750361e-02 -9.96138270e-01  6.27746234e-03
#  -5.57414427e-01]

# %% [markdown]
# 13-imprima o par "feature names" com os "coefficients"

# %%
list(zip(feature_cols, linreg.coef_))
# Out:
# [('CRIM', -0.1144289030662819),
#  ('ZN', 0.05712997804798281),
#  ('INDUS', 0.03830028239368256),
#  ('CHAS', 2.4285464082017265),
#  ('NOX', -21.23262356052942),
#  ('RM', 2.877234156006151),
#  ('AGE', 0.006911180936363715),
#  ('DIS', -1.4715826611839453),
#  ('RAD', 0.3057841971271422),
#  ('TAX', -0.010675036077891532),
#  ('PTRATIO', -0.996138269550691),
#  ('B', 0.006277462341291343),
#  ('LSTAT', -0.5574144267110059)]

# %% [markdown]
# 14-Faça uma previsão usando o conjunto de X de teste

# %%
y_pred = linreg.predict(X_test)
y_pred
# Out:
# array([32.37816533, 27.95684437, 18.07213891, 21.63166556, 18.93029508,
#        19.96277202, 32.2834674 , 18.06715668, 24.72989076, 26.85359369,
#        27.23326816, 28.57021239, 21.18778302, 26.94393815, 23.37892579,
#        20.89176865, 17.11746934, 37.73997945, 30.51980066,  8.44489436,
#        20.86557977, 16.21989418, 25.13605925, 24.77658813, 31.40497629,
#        11.02741407, 13.82097563, 16.80208261, 35.94637198, 14.7155729 ,
#        21.23939821, 14.15079469, 42.72492585, 17.83887162, 21.84610225,
#        20.40178099, 17.50287927, 27.00093206,  9.80760408, 20.00288662,
#        24.27066782, 21.06719021, 29.47089776, 16.48482565, 19.38852695,
#        14.54778282, 39.39838319, 18.09810655, 26.22164983, 20.60676525,
#        25.09994066, 24.48366723, 25.02297948, 26.84986898,  5.01517985,
#        24.12809513, 10.72843392, 26.83178157, 16.8023533 , 35.48142073,
#        19.50937911, 27.43260347, 16.58016763, 19.151488  , 10.9990262 ,
# ...

# %% [markdown]
# 15-Mostre a margem de error, usando o método "Root Mean Squared Error (RMSE)"

# %%
from sklearn import metrics
import numpy as np

print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 4.6795048238087835

# %% [markdown]
# 16-Existe uma forma de melhorar essa margem para que fique menor? Se sim, como seria?

# %% [markdown]
# Sim, existe. Seria assim:

# %%
new_feature_cols = ['ZN', 'CHAS', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# use the list to select a subset of the original DataFrame
X = data[new_feature_cols]

# select a Series from the DataFrame
y = data.MEDV

# split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# fit the model to the training data (learn the coefficients)
linreg.fit(X_train, y_train)

# make predictions on the testing set
y_pred = linreg.predict(X_test)

# compute the RMSE of our predictions
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 4.604542178989365
